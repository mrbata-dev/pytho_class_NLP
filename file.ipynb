# %%
f=open('/home/secret/Documents/pythonVirtualEnv/file.txt', mode='a')
# f.read()

# f.write('This is NLP')
f.write(' This is appended text')

f.close()
# Out:
# 22

# %%
fx=open('new.txt', mode='x')

# %%
fwr = open('/home/secret/Documents/pythonVirtualEnv/file.txt', mode='w+')
fwr.write('Hello world')
fwr.read()
fwr.close()
